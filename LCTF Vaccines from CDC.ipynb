# %%
import requests as re
import pandas as pd

# %%
url = 'https://covid.cdc.gov/covid-data-tracker/COVIDData/getAjaxData?id=vaccination_ltc_data'

params = dict(
    origin='Chicago,IL',
    destination='Los+Angeles,CA',
    waypoints='Joplin,MO|Oklahoma+City,OK',
    sensor='false'
)

resp = re.get(url=url)
data = resp.json()

# %%
df_vaccinations_ltcf = pd.DataFrame(data['vaccination_ltc_data'])

# %%
df_vaccinations_ltcf.head(10)
# Out:
#          Date Location ShortName              LongName  Census2019  \
# 0  2021-02-10       AK       AKA                Alaska      731545
# 1  2021-02-10       AL       ALA               Alabama     4903185
# 2  2021-02-10       AR       ARA              Arkansas     3017804
# 3  2021-02-10       AS       ASA        American Samoa       55689
# 4  2021-02-10       AZ       AZA               Arizona     7278717
# 5  2021-02-10      BP2       BP2     Bureau of Prisons           0
# 6  2021-02-10       CA       CAA            California    39512223
# 7  2021-02-10       CO       COA              Colorado     5758736
# 8  2021-02-10       CT       CTA           Connecticut     3565287
# 9  2021-02-10       DC       DCA  District of Columbia      705749
#
#    Administered_Fed_LTC  Administered_Fed_LTC_Dose1  \
# 0                  4642                        3587
# 1                 56610                       41911
# 2                 20813                       17714
# ...

# %%
now = datetime.now()
dt_string = now.strftime("%d%m%Y")

# %%
df_vaccinations_ltcf.
